# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
engine = create_engine("postgresql+psycopg2://postgres:postgres@localhost:5432/lahman")

# %%
df = pd.read_sql("SELECT * FROM pitching;", con=engine)
df.head()
# Out:
#     playerid  yearid  stint teamid lgid   w   l   g  gs  cg  ...  ibb  wp  \
# 0  bechtge01    1871      1    PH1   NA   1   2   3   3   2  ...  NaN NaN
# 1  brainas01    1871      1    WS3   NA  12  15  30  30  30  ...  NaN NaN
# 2  fergubo01    1871      1    NY2   NA   0   0   1   0   0  ...  NaN NaN
# 3  fishech01    1871      1    RC1   NA   4  16  24  24  22  ...  NaN NaN
# 4  fleetfr01    1871      1    NY2   NA   0   1   1   1   1  ...  NaN NaN
#
#    hbp  bk  bfp  gf    r  sh  sf  gidp
# 0  NaN   0  NaN NaN   42 NaN NaN   NaN
# 1  NaN   0  NaN NaN  292 NaN NaN   NaN
# 2  NaN   0  NaN NaN    9 NaN NaN   NaN
# 3  NaN   0  NaN NaN  257 NaN NaN   NaN
# 4  NaN   0  NaN NaN   21 NaN NaN   NaN
#
# [5 rows x 30 columns]

# %%
tables = pd.read_sql("""SELECT table_name
                        FROM information_schema.tables
                        WHERE table_schema = 'public'
                        ORDER BY table_name;""", con=engine)

# %%
tables.table_name
# Out:
# 0             allstarfull
# 1             appearances
# 2          awardsmanagers
# 3           awardsplayers
# 4     awardssharemanagers
# 5      awardsshareplayers
# 6                 batting
# 7             battingpost
# 8          collegeplaying
# 9                fielding
# 10             fieldingof
# 11        fieldingofsplit
# 12           fieldingpost
# 13             halloffame
# 14              homegames
# 15               managers
# 16           managershalf
# 17                  parks
# 18                 people
# 19               pitching
# 20           pitchingpost
# 21               salaries
# 22                schools
# 23             seriespost
# 24                  teams
# 25        teamsfranchises
# 26              teamshalf
# Name: table_name, dtype: object

# %%
lahman = {}
for table in tables.table_name:
    query = 'SELECT * FROM ' + str(table)
    df = pd.read_sql(query, con=engine)
    lahman[table] = df

# %%
lahman
# Out:
# {'allstarfull':        playerid  yearid  gamenum        gameid teamid lgid   gp  startingpos
#  0     gomezle01    1933        0  ALS193307060    NYA   AL  1.0          1.0
#  1     ferreri01    1933        0  ALS193307060    BOS   AL  1.0          2.0
#  2     gehrilo01    1933        0  ALS193307060    NYA   AL  1.0          3.0
#  3     gehrich01    1933        0  ALS193307060    DET   AL  1.0          4.0
#  4     dykesji01    1933        0  ALS193307060    CHA   AL  1.0          5.0
#  ...         ...     ...      ...           ...    ...  ...  ...          ...
#  5143  seageco01    2016        0  ALS201607120    LAN   NL  1.0          NaN
#  5144  strasst01    2016        0  ALS201607120    WAS   NL  0.0          NaN
#  5145  syndeno01    2016        0  ALS201607120    NYN   NL  0.0          NaN
#  5146  teherju01    2016        0  ALS201607120    ATL   NL  1.0          NaN
#  5147  zobribe01    2016        0  ALS201607120    CHN   NL  1.0          4.0
#
# ...

# %%
lahman.keys()
# Out:
# dict_keys(['allstarfull', 'appearances', 'awardsmanagers', 'awardsplayers', 'awardssharemanagers', 'awardsshareplayers', 'batting', 'battingpost', 'collegeplaying', 'fielding', 'fieldingof', 'fieldingofsplit', 'fieldingpost', 'halloffame', 'homegames', 'managers', 'managershalf', 'parks', 'people', 'pitching', 'pitchingpost', 'salaries', 'schools', 'seriespost', 'teams', 'teamsfranchises', 'teamshalf'])

# %%
lahman['fielding']
# Out:
#          playerid  yearid  stint teamid lgid pos    g     gs  innouts   po  \
# 0       abercda01    1871      1    TRO   NA  SS    1    NaN      NaN    1
# 1        addybo01    1871      1    RC1   NA  2B   22    NaN      NaN   67
# 2        addybo01    1871      1    RC1   NA  SS    3    NaN      NaN    8
# 3       allisar01    1871      1    CL1   NA  2B    2    NaN      NaN    1
# 4       allisar01    1871      1    CL1   NA  OF   29    NaN      NaN   51
# ...           ...     ...    ...    ...  ...  ..  ...    ...      ...  ...
# 136810  zobribe01    2016      1    CHN   NL  2B  119  113.0   2929.0  177
# 136811  zobribe01    2016      1    CHN   NL  OF   46   29.0    859.0   43
# 136812  zobribe01    2016      1    CHN   NL  SS    1    0.0      6.0    0
# 136813  zuninmi01    2016      1    SEA   AL   C   52   48.0   1331.0  400
# 136814   zychto01    2016      1    SEA   AL   P   12    0.0     41.0    0
#
#             a     e    dp   pb  wp    sb   cs  zr
# ...

# %% [markdown]
# Question 1
# a. Find all players in the database who played at Vanderbilt University.
# b. Create a list showing each player’s first and last names as well as the total salary they earned in the major leagues.
# c. Sort this list in descending order by the total salary earned.
# d. Which Vanderbilt player earned the most money in the majors?

# %%
lahman['schools'][lahman['schools'].schoolname.str.startswith('Vand')]
# Out:
#      schoolid             schoolname schoolcity schoolstate schoolnick
# 1110    vandy  Vanderbilt University  Nashville          TN        USA

# %%
#part a
vandyplayers = lahman['people'][lahman['people']['playerid'].isin(lahman['collegeplaying'][lahman['collegeplaying']['schoolid']=='vandy']['playerid'])]
print(len(vandyplayers['namegiven']))
vandyplayers['namegiven']
# Out:
# 24
# 282          Pedro Manuel
# 958        Michael Joseph
# 2989        Nicholas John
# 3292         Cyril Wilson
# 3466          Jose Manuel
# 4990         Charles Akin
# 5457          Ryan Edward
# 6605        Sonny Douglas
# 7467               Harvey
# 8861         Matthew John
# 9941        Jensen Daniel
# 10451       Charles Scott
# 11787       Michael David
# 11969       William Allen
# 12138     Charles Malcolm
# 13248      Joshua William
# 13867        David Taylor
# 13889        Mark William
# 14402       Antoan Edward
# 15172       Scott Douglas
# 15629        Truett Banks
# 16284        Jeremy Bryan
# 18542       Michael Henry
# 19059    Joshua Alexander
# Name: namegiven, dtype: object

# %%
sumsalary=lahman['salaries'].groupby('playerid').agg('sum').drop(columns=['yearid'])
vandysalary = vandyplayers.merge(sumsalary, on='playerid').sort_values('salary', ascending=False)
vandysalary.loc[:,['namegiven','namefirst','namelast','salary']]
# Out:
#          namegiven namefirst    namelast      salary
# 11    David Taylor     David       Price  81851296.0
# 0     Pedro Manuel     Pedro     Alvarez  20681704.0
# 12    Mark William      Mark       Prior  12800000.0
# 13   Scott Douglas     Scott   Sanderson  10750000.0
# 9    Michael David      Mike       Minor   6837500.0
# 3      Jose Manuel      Joey        Cora   5622500.0
# 4      Ryan Edward      Ryan    Flaherty   4061000.0
# 10  Joshua William      Josh        Paul   2640000.0
# 1   Michael Joseph      Mike      Baxter   2094418.0
# 5    Sonny Douglas     Sonny        Gray   1542500.0
# 7    Jensen Daniel    Jensen       Lewis   1234000.0
# 6     Matthew John      Matt        Kata   1060000.0
# 2    Nicholas John      Nick  Christiani    500000.0
# 14    Jeremy Bryan    Jeremy      Sowers    384800.0
# 8    Charles Scott    Scotti     Madison    135000.0

# %% [markdown]
# Question 2
# Using the fielding table, group players into three groups based on their position: label players with position OF as "Outfield", those with position "SS", "1B", "2B", and "3B" as "Infield", and those with position "P" or "C" as "Battery". Determine the number of putouts made by each of these three groups in 2016.

# %%
posgroup = {'Battery':['P','C'],'Infield':['SS','1B','2B','3B'],'Outfield':['OF']}
def grouppos(pos):
    if pos in posgroup['Battery']:
        return 'Battery'
    elif pos in posgroup['Infield']:
        return 'Infield'
    elif pos in posgroup['Outfield']:
        return 'Outfield'

# %%
lahman['fielding']['PosGroup'] = lahman['fielding']['pos'].apply(grouppos)

# %%
lahman['fielding'][lahman['fielding']['yearid']==2016].loc[:,['PosGroup','po']].groupby('PosGroup').agg('sum')
# Out:
#              po
# PosGroup
# Battery   41424
# Infield   58934
# Outfield  29560

# %% [markdown]
# Question 3
# a. From 1970 – 2016, what is the largest number of wins for a team that did not win the world series?
# b. What is the smallest number of wins for a team that did win the world series?
# c. Doing this will probably result in an unusually small number of wins for a world series champion – determine why this is the case.
# d. Then redo your query, excluding the problem year.
# e. How often from 1970 – 2016 was it the case that a team with the most wins also won the world series?
# f. What percentage of the time?

# %%
lahman['teams'][(lahman['teams']['wswin']=='Y')&
                (lahman['teams']['yearid']<=2016)&
                (lahman['teams']['yearid']>=1970)].sort_values('w').iloc[0,[40,0,8]]
# Out:
# name      Los Angeles Dodgers
# yearid                   1981
# w                          63
# Name: 1824, dtype: object

# %%
lahman['teams'][(lahman['teams']['wswin']=='Y')&
                (lahman['teams']['yearid']<=2016)&
                (lahman['teams']['yearid']>=1970)&
               (lahman['teams']['yearid']!=1981)].sort_values('w').iloc[0,[40,0,8]]
# Out:
# name      St. Louis Cardinals
# yearid                   2006
# w                          83
# Name: 2530, dtype: object

# %%
mostwins = lahman['teams'][(lahman['teams']['yearid']<=2016)&
                (lahman['teams']['yearid']>=1970)].sort_values(['yearid','w','wswin'], ascending=[True, False,False]).drop_duplicates(subset=['yearid'], keep='first').dropna(subset=['wswin'])
mostwins[(mostwins['wswin']=='Y')].sort_values('w').iloc[:,[40,0,8]].sort_values('yearid')
# Out:
#                    name  yearid    w
# 1542  Baltimore Orioles    1970  108
# 1667    Cincinnati Reds    1975  108
# 1691    Cincinnati Reds    1976  102
# 1750   New York Yankees    1978  100
# 1899     Detroit Tigers    1984  104
# 1959      New York Mets    1986  108
# 2038  Oakland Athletics    1989   99
# 2283   New York Yankees    1998  114
# 2538     Boston Red Sox    2007   96
# 2612   New York Yankees    2009  103
# 2718     Boston Red Sox    2013   97
# 2810       Chicago Cubs    2016  103

# %%
print(len(mostwins[(mostwins['wswin']=='Y')].sort_values('w').iloc[:,[40,0,8]].sort_values('yearid'))/len(mostwins))
# Out:
# 0.2608695652173913

# %% [markdown]
# Question 4
# Which managers have won the TSN Manager of the Year award in both the National League (NL) and the American League (AL)? Give their full name and the teams that they were managing when they won the award.

# %%
lahman['awardsmanagers'][lahman['awardsmanagers']['awardid'].str.startswith('TSN Ma')]
# Out:
#       playerid                  awardid  yearid lgid   tie notes
# 63   mccarjo99  TSN Manager of the Year    1936   ML  None  None
# 64   mckecbi01  TSN Manager of the Year    1937   ML  None  None
# 65   mccarjo99  TSN Manager of the Year    1938   ML  None  None
# 66   durocle01  TSN Manager of the Year    1939   ML  None  None
# 67   mckecbi01  TSN Manager of the Year    1940   ML  None  None
# ..         ...                      ...     ...  ...   ...   ...
# 168  hurdlcl01  TSN Manager of the Year    2013   NL  None  None
# 169  showabu99  TSN Manager of the Year    2014   AL  None  None
# 170  willima04  TSN Manager of the Year    2014   NL  None  None
# 171  molitpa01  TSN Manager of the Year    2015   AL  None  None
# 172  collite99  TSN Manager of the Year    2015   NL  None  None
#
# [110 rows x 6 columns]

# %%
awardcount = lahman['awardsmanagers'][lahman['awardsmanagers']['lgid'].isin(['NL','AL'])].groupby(['playerid','awardid']).nunique().reset_index()
q2players = awardcount[(awardcount['awardid'].str.startswith('TSN'))&(awardcount['lgid']>1)]['playerid']

# %%
q2list = lahman['awardsmanagers'][lahman['awardsmanagers']['playerid'].isin(q2players)&lahman['awardsmanagers']['awardid'].str.startswith('TSN')]

# %%
q2list.merge(lahman['people'].iloc[:,[0,13,14,15]], on='playerid')
# Out:
#     playerid                  awardid  yearid lgid   tie notes namefirst  \
# 0  leylaji99  TSN Manager of the Year    1988   NL  None  None       Jim
# 1  leylaji99  TSN Manager of the Year    1990   NL  None  None       Jim
# 2  leylaji99  TSN Manager of the Year    1992   NL  None  None       Jim
# 3  leylaji99  TSN Manager of the Year    2006   AL  None  None       Jim
# 4  johnsda02  TSN Manager of the Year    1997   AL  None  None     Davey
# 5  johnsda02  TSN Manager of the Year    2012   NL  None  None     Davey
#
#   namelast      namegiven
# 0  Leyland  James Richard
# 1  Leyland  James Richard
# 2  Leyland  James Richard
# 3  Leyland  James Richard
# 4  Johnson    David Allen
# 5  Johnson    David Allen

# %% [markdown]
# Question 5
# Analyze all the colleges in the state of Tennessee.
# a. Which college has had the most success in the major leagues?
# b. Use whatever metric for success you like - number of players, number of games, salaries, world series wins, etc.

# %%
tnschoolid = lahman['schools'][lahman['schools'].schoolstate =='TN']['schoolid']

# %%
lastschool = lahman['collegeplaying'].sort_values('yearid').drop_duplicates(subset=['playerid'], keep='last')
tnplayerid = lastschool[lastschool['schoolid'].isin(tnschoolid)]['playerid']

# %%
tnplayers = tnplayerid.to_frame().merge(lahman['awardsplayers'][lahman['awardsplayers']['playerid'].isin(tnplayerid)].groupby('playerid')['awardid'].count(),on='playerid',how='left')

# %%
tnplayers= tnplayers.merge(lahman['salaries'][lahman['salaries']['playerid'].isin(tnplayerid)].groupby('playerid')['salary'].sum(),how='left', on='playerid')
tnplayers
# Out:
#       playerid  awardid     salary
# 0    dextech01      NaN        NaN
# 1    sandewa01      NaN        NaN
# 2    mcelvpr01      NaN        NaN
# 3    weaveor01      NaN        NaN
# 4    allenfr01      NaN        NaN
# ..         ...      ...        ...
# 146  chrisni01      NaN   500000.0
# 147  brothre01      NaN  2873000.0
# 148  minormi01      NaN  6837500.0
# 149  pryorst01      NaN   492200.0
# 150   grayso01      NaN  1542500.0
#
# [151 rows x 3 columns]

# %%
yptcol = ['yearid','playerid','teamid']
posttable = ['battingpost','pitchingpost','fieldingpost']
wsplayers = pd.DataFrame()
for tab in posttable:
    wsplayers = wsplayers.append(lahman[tab].loc[:,yptcol][lahman[tab]['round']=='WS'])

wsplayers.drop_duplicates(inplace=True)
wsapp = wsplayers[wsplayers['playerid'].isin(tnplayers['playerid'])].groupby('playerid').count().rename(columns={'teamid':'wsapp'})['wsapp']
tnplayers= tnplayers.merge(wsapp, how='left', on='playerid')
tnplayers
# Out:
# playerid
# anderda02    1
# baileed01    1
# barbetu01    1
# bernadw01    1
# borboju01    1
# bridgto01    4
# brownto05    1
# burkech01    1
# garneph01    1
# goodsed01    1
# grimsro02    1
# hammaat01    1
# heltoto01    1
# hendrha01    1
# hochelu01    1
# honeyri01    3
# kingra01     1
# mcmicgr01    2
# mooneji01    1
# mooreji02    2
# priceda01    1
# sandesc01    1
# shelbjo01    2
# shielsc01    1
# stewaji01    1
# trammbu01    1
# walkeja01    1
# weathda01    1
# Name: wsapp, dtype: int64

# %%
tntopschools = tnplayers.merge(lastschool, how='left',on='playerid').drop(columns='yearid')
tntopschools = tntopschools.merge(lahman['schools'].loc[:,['schoolid','schoolname']], how='left', on='schoolid')
tntopschools.drop(columns=['playerid','schoolid'], inplace=True)
tntop = tntopschools.groupby('schoolname').agg({'awardid':'sum','salary':'mean','wsapp':'sum'}).sort_values(['awardid','salary','wsapp'], ascending=False)
tntop['salary'] = tntop['salary'].map('${:,.2f}'.format)
tntop
# Out:
#                                                awardid          salary  wsapp
# schoolname
# University of Tennessee                           25.0  $18,170,290.00   16.0
# Vanderbilt University                              6.0   $9,956,765.57    3.0
# University of Memphis                              1.0   $9,898,618.00    1.0
# Motlow State Community College                     0.0  $25,058,499.00    1.0
# Tennessee Wesleyan College                         0.0  $16,713,333.00    1.0
# Carson-Newman College                              0.0  $15,435,000.00    0.0
# Austin Peay State University                       0.0  $10,975,600.00    2.0
# Lincoln Memorial University                        0.0  $10,952,500.00    1.0
# Lambuth University                                 0.0   $8,070,000.00    1.0
# East Tennessee State University                    0.0   $3,803,334.00    3.0
# Lipscomb University                                0.0   $2,873,000.00    0.0
# ...
